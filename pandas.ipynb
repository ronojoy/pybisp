# %%
import pandas as pd
import numpy as np
import pdb
import matplotlib.pyplot as plt
from pandas import DataFrame, read_csv

# %%
N = 60
t = arange(N)                  # sampling times
dw = np.random.randn(N)        # Wiener increments   
x = np.cumsum(dw)              # Brownian path    
plot(t, x)
xlabel('t')
ylabel('x')

#Opening a datafile:
f = open('data_new.txt', 'wb')
f.write(str(x))
f.write(str(t))
'''
Writing the output into the file: str() converts to string:
'''
f.close()#Closing the file:
data = pd.read_csv('data_new.txt')
#print pd.read_csv('data_new.txt')(or)
data
# Out:
#   [-0.6118556   1.46118286  1.77985347  0.97245895  1.0253146  -0.11049725
# 0    1.03061658  1.77561506  0.95436266  0.490939...

# %%
# load the CSV into a DataFrame object
#dt = pd.DataFrame(t,x,index=times)

#df = pd.read_csv('.........csv')
