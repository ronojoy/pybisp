# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import pybisp as pb
import pandas as pd
from numpy import *

# %%
data = loadtxt("D500we.csv")

# %%
## plotting logProb as a function of theta
# %matplotlib inline
thetaExtent = np.linspace(300, 700, 200)
#print thetaExtent
inference.plotLogProb(thetaExtent)
